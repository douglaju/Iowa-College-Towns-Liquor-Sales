# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask.dataframe as dd
import dask.array as da
import dask.bag as db

# %% [markdown]
# ### Data Prep

# %%
ddf = dd.read_parquet('./data/parquet/data-*.parquet')

# %%
#check column names
ddf.columns
# Out:
# Index(['index', 'Invoice/Item Number', 'Date', 'Store Number', 'Store Name',
#        'Address', 'City', 'Zip Code', 'Store Location', 'County Number',
#        'County', 'Category', 'Category Name', 'Vendor Number', 'Vendor Name',
#        'Item Number', 'Item Description', 'Pack', 'Bottle Volume (ml)',
#        'State Bottle Cost', 'State Bottle Retail', 'Bottles Sold',
#        'Sale (Dollars)', 'Volume Sold (Liters)', 'Volume Sold (Gallons)'],
#       dtype='object')

# %%
#check size of file for correct number of rows
ddf.shape[0].compute()
# Out:
# 23346088

# %%
#split main df into smaller subcategory df's
county_info = ['County Number', 'County']
vendor_info = ['Vendor Name', 'Vendor Number']
product_info = ['Item Number', 'Item Description', 'Pack', 'Bottle Volume (ml)']
price_info = ['Item Number', 'State Bottle Cost', 'State Bottle Retail', 'Date']
store_info = ['Store Number', 'Store Name', 'City', 'Zip Code', 'County Number', 'Date']
transaction_info = ['Invoice/Item Number', 'Date', 'Store Number', 'Category', 
                    'Vendor Number', 'Item Number', 'Bottles Sold', 'Sale (Dollars)']
category_info = ['Category', 'Category Name']

# %% [markdown]
# ### Counties Sub-Frame

# %%
#select county info columns
ddf = ddf[county_info]

# %%
#get rid of duplicate county rows
ddf = ddf.drop_duplicates().compute()

# %%
ddf
# Out:
#        County Number       County
# 0               68.0       Monroe
# 1               17.0  Cerro Gordo
# 2                1.0        Adair
# 3               85.0        Story
# 4               21.0         Clay
# ...              ...          ...
# 29060           26.0        DAVIS
# 34735           13.0      CALHOUN
# 40134           93.0        WAYNE
# 12288            2.0        ADAMS
# 5977             NaN      EL PASO
#
# [202 rows x 2 columns]

# %%
#check for NA county numbers
ddf[ddf['County Number'].isna()]
# Out:
#       County Number   County
# 2052            NaN     None
# 5977            NaN  EL PASO

# %%
#drop rows w/ NA for county number
ddf = ddf[~ddf['County Number'].isna()]

#add in row for unknown
ddf = ddf.append(pd.Series({'County Number': 999, 'County': 'Unknown'}), ignore_index = True)
ddf
# Out:
#      County Number       County
# 0             68.0       Monroe
# 1             17.0  Cerro Gordo
# 2              1.0        Adair
# 3             85.0        Story
# 4             21.0         Clay
# ..             ...          ...
# 196           26.0        DAVIS
# 197           13.0      CALHOUN
# 198           93.0        WAYNE
# 199            2.0        ADAMS
# 200          999.0      Unknown
#
# [201 rows x 2 columns]

# %%
#gets rid of duplicates from typos, mispelling, etc
ddf = ddf.loc[ddf['County Number'].drop_duplicates().index]

# %%
#contains all 99 Iowa counties, plus row for unknown
ddf
# Out:
#      County Number       County
# 0             68.0       Monroe
# 1             17.0  Cerro Gordo
# 2              1.0        Adair
# 3             85.0        Story
# 4             21.0         Clay
# ..             ...          ...
# 95            26.0        Davis
# 96            36.0      Fremont
# 97            93.0        Wayne
# 98             2.0        Adams
# 200          999.0      Unknown
#
# [100 rows x 2 columns]

# %%
#convert county numbers to integer type
ddf.loc[:, 'County Number'] = ddf['County Number'].astype(int)

# %%
#rename columns
ddf.columns = ['CountyNumber', 'County']

# %%
#export df as csv
ddf.to_csv('./data/county.csv')

# %% [markdown]
# ### Vendors Sub-Frame

# %%
#reread in parquet files
ddf = dd.read_parquet('./data/parquet/data-*.parquet')

# %%
#select vendor info columns
ddf = ddf[vendor_info]

# %%
#drop duplicate vendor rows
ddf = ddf.drop_duplicates().compute()

# %%
#rename columns
ddf.columns = ['VendorName', 'VendorNumber']

# %%
#prepping to check for NA values in columns
idx_na = ddf['VendorNumber'].isna()
name_na = ddf['VendorName'].isna()

# %%
#checks for NA vendor number
ddf[idx_na]
# Out:
#                  VendorName  VendorNumber
# 37814                  None           NaN
# 740    Reservoir Distillery           NaN

# %%
#checks for NA vendor name
ddf[name_na]
# Out:
#       VendorName  VendorNumber
# 37814       None           NaN

# %%
ddf
# Out:
#                          VendorName  VendorNumber
# 0                    Luxco-St Louis         434.0
# 1      WILLIAM GRANT AND SONS, INC.         240.0
# 3                   Jim Beam Brands          65.0
# 4                 Sazerac Co., Inc.         421.0
# 5         Phillips Beverage Company         380.0
# ...                             ...           ...
# 35836         Leatherbee Distillers         252.0
# 6471          Breuckelen Distilling         119.0
# 37654              Sovereign Brands         482.0
# 29558            Phenix Brands, LLC         386.0
# 23789                Tanteo Tequila         462.0
#
# [556 rows x 2 columns]

# %%
#removes NA vendor name row
ddf = ddf[~ddf['VendorNumber'].isna()]

# %%
ddf
# Out:
#                          VendorName  VendorNumber
# 0                    Luxco-St Louis         434.0
# 1      WILLIAM GRANT AND SONS, INC.         240.0
# 3                   Jim Beam Brands          65.0
# 4                 Sazerac Co., Inc.         421.0
# 5         Phillips Beverage Company         380.0
# ...                             ...           ...
# 35836         Leatherbee Distillers         252.0
# 6471          Breuckelen Distilling         119.0
# 37654              Sovereign Brands         482.0
# 29558            Phenix Brands, LLC         386.0
# 23789                Tanteo Tequila         462.0
#
# [554 rows x 2 columns]

# %%
#checking for repeat names
ddf['VendorName'].value_counts()
# Out:
# Casa 1921 LLC                        2
# Levecke Corporation                  2
# Luxco-St Louis                       1
# Old Elk Distilleries LLC             1
# HPSepicurean LLC / Preiss Imports    1
#                                     ..
# The Country Vintner                  1
# Brown Forman Corp.                   1
# DIAGEO AMERICAS                      1
# Iconic Brands, Inc.                  1
# Tanteo Tequila                       1
# Name: VendorName, Length: 552, dtype: int64

# %%
#check for repeat vendor numbers
ddf['VendorNumber'].value_counts()
# Out:
# 192.0    4
# 391.0    4
# 803.0    4
# 214.0    4
# 338.0    3
#         ..
# 216.0    1
# 269.0    1
# 583.0    1
# 548.0    1
# 462.0    1
# Name: VendorNumber, Length: 400, dtype: int64

# %%
#removes duplicate vendor numbers
ddf = ddf.drop_duplicates(subset = ['VendorNumber'])

# %%
ddf
# Out:
#                          VendorName  VendorNumber
# 0                    Luxco-St Louis         434.0
# 1      WILLIAM GRANT AND SONS, INC.         240.0
# 3                   Jim Beam Brands          65.0
# 4                 Sazerac Co., Inc.         421.0
# 5         Phillips Beverage Company         380.0
# ...                             ...           ...
# 16631     Journeyman Distillery LLC         191.0
# 35836         Leatherbee Distillers         252.0
# 6471          Breuckelen Distilling         119.0
# 29558            Phenix Brands, LLC         386.0
# 23789                Tanteo Tequila         462.0
#
# [400 rows x 2 columns]

# %%
#checks that all value counts are now 1
ddf['VendorNumber'].value_counts(dropna = False)
# Out:
# 434.0    1
# 607.0    1
# 617.0    1
# 602.0    1
# 554.0    1
#         ..
# 465.0    1
# 209.0    1
# 118.0    1
# 108.0    1
# 462.0    1
# Name: VendorNumber, Length: 400, dtype: int64

# %%
#add in row for unknown
ddf = ddf.append(pd.Series({'VendorNumber': 9999, 'VendorName': 'Unknown'}), ignore_index = True)

# %%
ddf
# Out:
#                        VendorName  VendorNumber
# 0                  Luxco-St Louis         434.0
# 1    WILLIAM GRANT AND SONS, INC.         240.0
# 2                 Jim Beam Brands          65.0
# 3               Sazerac Co., Inc.         421.0
# 4       Phillips Beverage Company         380.0
# ..                            ...           ...
# 396         Leatherbee Distillers         252.0
# 397         Breuckelen Distilling         119.0
# 398            Phenix Brands, LLC         386.0
# 399                Tanteo Tequila         462.0
# 400                       Unknown        9999.0
#
# [401 rows x 2 columns]

# %%
#checks that vendor numbers are integers
ddf['VendorNumber'].describe()
# Out:
# count     401.000000
# mean      436.802993
# std       521.376643
# min        10.000000
# 25%       252.000000
# 50%       410.000000
# 75%       566.000000
# max      9999.000000
# Name: VendorNumber, dtype: float64

# %%
#export df as csv
ddf.to_csv('./data/vendor.csv')

# %% [markdown]
# ### Products Sub-Frame

# %%
#reread in parquet files
ddf = dd.read_parquet('./data/parquet/data-*.parquet')

# %%
#select product info columns
ddf = ddf[product_info]

# %%
#drop duplicate product rows
ddf = ddf.drop_duplicates().compute()

# %%
ddf
# Out:
#       Item Number                      Item Description  Pack  \
# 0           36308                         Hawkeye Vodka     6
# 1           45888          Sailor Jerry Spiced Navy Rum     6
# 2           55084           Paramount Blackberry Brandy    24
# 3           67557                 Kamora Coffee Liqueur    12
# 4           77487                     Tortilla Gold Dss    12
# ...           ...                                   ...   ...
# 26959      901036                        Apricot Grappa     1
# 34073      973579               Crave Chocolate Truffle    12
# 11453      902750                    Margaritaville Oro    12
# 23449      967220                Villa Massa Limoncello     6
# 23789      904010  Tanteo Jalapeno Tequila( do not use)     6
#
#        Bottle Volume (ml)
# 0                    1750
# 1                    1750
# 2                     375
# 3                    1000
# 4                    1000
# ...                   ...
# 26959                1000
# 34073                 750
# 11453                1000
# 23449                 750
# 23789                 750
#
# [13479 rows x 4 columns]

# %%
#rename columns
ddf.columns = ['ItemNumber', 'ItemDescription', 'Pack', 'BottleVolume(ml)']

# %%
#prepping to check for NA values in columns
idx_na = ddf['ItemNumber'].isna()
desc_na = ddf['ItemDescription'].isna()
pack_na = ddf['Pack'].isna()
vol_na = ddf['BottleVolume(ml)'].isna()

# %%
#checks for NA item number
ddf[idx_na]
# Out:
# Empty DataFrame
# Columns: [ItemNumber, ItemDescription, Pack, BottleVolume(ml)]
# Index: []

# %%
#checks for NA item description
ddf[desc_na]
# Out:
# Empty DataFrame
# Columns: [ItemNumber, ItemDescription, Pack, BottleVolume(ml)]
# Index: []

# %%
#checks for NA pack
ddf[pack_na]
# Out:
# Empty DataFrame
# Columns: [ItemNumber, ItemDescription, Pack, BottleVolume(ml)]
# Index: []

# %%
#checks for NA bottle volume
ddf[vol_na]
# Out:
# Empty DataFrame
# Columns: [ItemNumber, ItemDescription, Pack, BottleVolume(ml)]
# Index: []

# %%
#check for repeat item numbers
ddf['ItemNumber'].value_counts()
# Out:
# 965266    7
# 984160    6
# 16906     6
# 22219     6
# 984393    5
#          ..
# 982785    1
# 35221     1
# 904006    1
# 902749    1
# 904010    1
# Name: ItemNumber, Length: 11013, dtype: int64

# %%
#removes duplicate item numbers
ddf = ddf.drop_duplicates(subset = ['ItemNumber'])

# %%
#checks that all value counts are now 1
ddf['ItemNumber'].value_counts(dropna = False)
# Out:
# 36308     1
# 100246    1
# 78059     1
# 989502    1
# 100812    1
#          ..
# 904118    1
# 902968    1
# 936020    1
# 900002    1
# 904010    1
# Name: ItemNumber, Length: 11013, dtype: int64

# %%
ddf
# Out:
#       ItemNumber                       ItemDescription  Pack  BottleVolume(ml)
# 0          36308                         Hawkeye Vodka     6              1750
# 1          45888          Sailor Jerry Spiced Navy Rum     6              1750
# 2          55084           Paramount Blackberry Brandy    24               375
# 3          67557                 Kamora Coffee Liqueur    12              1000
# 4          77487                     Tortilla Gold Dss    12              1000
# ...          ...                                   ...   ...               ...
# 26959     901036                        Apricot Grappa     1              1000
# 34073     973579               Crave Chocolate Truffle    12               750
# 11453     902750                    Margaritaville Oro    12              1000
# 23449     967220                Villa Massa Limoncello     6               750
# 23789     904010  Tanteo Jalapeno Tequila( do not use)     6               750
#
# [11013 rows x 4 columns]

# %%
#identifies row with letter in item number
ddf[ddf['ItemNumber'] == 'x904631']
# Out:
#       ItemNumber                       ItemDescription  Pack  BottleVolume(ml)
# 16474    x904631  Tanqueray Gin Mini - Use 904631 Code    12               500

# %%
#removes letter from item number
ddf = ddf.replace('x904631', '904631')

# %%
#checks to see if all value counts are still 1
ddf['ItemNumber'].value_counts(dropna = False)
# Out:
# 904631    2
# 36308     1
# 972427    1
# 26673     1
# 78059     1
#          ..
# 554       1
# 904118    1
# 902968    1
# 936020    1
# 904010    1
# Name: ItemNumber, Length: 11012, dtype: int64

# %%
#removes duplicate item numbers
ddf = ddf.drop_duplicates(subset = ['ItemNumber'])

# %%
#convert cols to integer type
ddf.loc[:, 'ItemNumber'] = ddf['ItemNumber'].astype(int)
ddf.loc[:, 'Pack'] = ddf['Pack'].astype(int)
ddf.loc[:, 'BottleVolume(ml)'] = ddf['BottleVolume(ml)'].astype(int)

# %%
#add in row for unknown
ddf = ddf.append(pd.Series({'ItemNumber': 99999999999, 'ItemDescription': 'Unknown', 'Pack': 0, 'BottleVolume(ml)': 0}), ignore_index = True)

# %%
ddf
# Out:
#         ItemNumber                       ItemDescription  Pack  \
# 0            36308                         Hawkeye Vodka     6
# 1            45888          Sailor Jerry Spiced Navy Rum     6
# 2            55084           Paramount Blackberry Brandy    24
# 3            67557                 Kamora Coffee Liqueur    12
# 4            77487                     Tortilla Gold Dss    12
# ...            ...                                   ...   ...
# 11008       973579               Crave Chocolate Truffle    12
# 11009       902750                    Margaritaville Oro    12
# 11010       967220                Villa Massa Limoncello     6
# 11011       904010  Tanteo Jalapeno Tequila( do not use)     6
# 11012  99999999999                               Unknown     0
#
#        BottleVolume(ml)
# 0                  1750
# 1                  1750
# 2                   375
# 3                  1000
# 4                  1000
# ...                 ...
# 11008               750
# 11009              1000
# 11010               750
# 11011               750
# 11012                 0
#
# [11013 rows x 4 columns]

# %%
#export df as csv
ddf.to_csv('./data/product.csv')

# %% [markdown]
# ### Prices Sub-Frame

# %%
#reread in parquet files
ddf = dd.read_parquet('./data/parquet/data-*.parquet')

# %%
#select price info columns
ddf = ddf[price_info]

# %%
#drop duplicate price rows
ddf = ddf.drop_duplicates().compute()

# %%
ddf
# Out:
#       Item Number  State Bottle Cost  State Bottle Retail        Date
# 0           36308               7.13                10.70  06/06/2012
# 1           45888              18.67                28.01  12/02/2013
# 2           55084               3.55                 5.33  04/06/2015
# 3           67557               8.39                12.59  10/22/2014
# 4           77487               4.51                 6.76  07/30/2013
# ...           ...                ...                  ...         ...
# 41042       43451               7.50                11.25  07/24/2013
# 41092       15677              16.49                24.74  08/26/2015
# 41103       73500              12.07                18.11  07/31/2014
# 41111       89099              23.48                35.22  03/19/2014
# 41154       33987              11.00                16.49  04/08/2013
#
# [3482700 rows x 4 columns]

# %%
#rename columns
ddf.columns = ['ItemNumber', 'StateBottleCost', 'StateBottleRetail', 'Date']

# %%
#removes letter from item number
ddf = ddf.replace('x904631', '904631')

# %%
#convert item numbers to integer type
ddf.loc[:, 'ItemNumber'] = ddf['ItemNumber'].astype(int)

# %%
#convert date column to date type
ddf['Date'] = pd.to_datetime(ddf['Date'], infer_datetime_format=True)

# %%
ddf
# Out:
#        ItemNumber  StateBottleCost  StateBottleRetail       Date
# 0           36308             7.13              10.70 2012-06-06
# 1           45888            18.67              28.01 2013-12-02
# 2           55084             3.55               5.33 2015-04-06
# 3           67557             8.39              12.59 2014-10-22
# 4           77487             4.51               6.76 2013-07-30
# ...           ...              ...                ...        ...
# 41042       43451             7.50              11.25 2013-07-24
# 41092       15677            16.49              24.74 2015-08-26
# 41103       73500            12.07              18.11 2014-07-31
# 41111       89099            23.48              35.22 2014-03-19
# 41154       33987            11.00              16.49 2013-04-08
#
# [3482700 rows x 4 columns]

# %%
#sory by date
ddf = ddf.sort_values(by='Date')

# %%
#filter out data before 2018
ddf = ddf[ddf['Date'] >= '2018-01-01']

# %%
ddf
# Out:
#        ItemNumber  StateBottleCost  StateBottleRetail       Date
# 28783       42723             7.49              11.24 2018-01-02
# 30030       54448            11.29              16.94 2018-01-02
# 26935       22151            12.45              18.68 2018-01-02
# 28770       34546             7.00              10.50 2018-01-02
# 26937       43316            11.99              17.99 2018-01-02
# ...           ...              ...                ...        ...
# 23386       89386             7.50              11.25 2022-02-28
# 30482       84166             7.50              11.25 2022-02-28
# 30466       34454             5.99               8.99 2022-02-28
# 23391       73054            25.00              37.50 2022-02-28
# 22334       27605            13.75              20.63 2022-02-28
#
# [1664363 rows x 4 columns]

# %%
#prepping to check for NA values in columns
idx_na = ddf['ItemNumber'].isna()
cost_na = ddf['StateBottleCost'].isna()
ret_na = ddf['StateBottleRetail'].isna()
date_na = ddf['Date'].isna()

# %%
#checks for NA item number
ddf[idx_na]
# Out:
# Empty DataFrame
# Columns: [ItemNumber, StateBottleCost, StateBottleRetail, Date]
# Index: []

# %%
#checks for NA bottle cost
ddf[cost_na]
# Out:
# Empty DataFrame
# Columns: [ItemNumber, StateBottleCost, StateBottleRetail, Date]
# Index: []

# %%
#checks for NA bottle retail
ddf[ret_na]
# Out:
# Empty DataFrame
# Columns: [ItemNumber, StateBottleCost, StateBottleRetail, Date]
# Index: []

# %%
#checks for NA date
ddf[date_na]
# Out:
# Empty DataFrame
# Columns: [ItemNumber, StateBottleCost, StateBottleRetail, Date]
# Index: []

# %%
#export df as csv
ddf.to_csv('./data/price.csv')

# %% [markdown]
# ### Stores Sub-Frame

# %%
#reread in parquet files
ddf = dd.read_parquet('./data/parquet/data-*.parquet')

# %%
#select store info columns
ddf = ddf[store_info]

# %%
#drop duplicate price rows
ddf = ddf.drop_duplicates().compute()

# %%
ddf
# Out:
#        Store Number                         Store Name             City  \
# 0              4011        Jim and Charlies Affiliated            ALBIA
# 1              2515  Hy-Vee Food Store #1 / Mason City       MASON CITY
# 2              3461            Hometown Foods / Stuart           STUART
# 3              2500        Hy-Vee Food Store #1 / Ames             AMES
# 4              2565        Hy-Vee Food Store / Spencer          SPENCER
# ...             ...                                ...              ...
# 2051           2478                    Prairie Meadows          ALTOONA
# 40676          4338           Randhawa's Travel Center        MELBOURNE
# 17487          2506          Hy-Vee #1044 / Burlington       BURLINGTON
# 20268          2619      Hy-Vee Wine and Spirits / WDM  WEST DES MOINES
# 34568          4829                     Central City 2       DES MOINES
#
#       Zip Code  County Number        Date
# 0        52531           68.0  06/06/2012
# 1        50401           17.0  12/02/2013
# 2        50250            1.0  04/06/2015
# 3        50010           85.0  10/22/2014
# 4        51301           21.0  07/30/2013
# ...        ...            ...         ...
# 2051     50009           77.0  02/13/2012
# 40676    50162           64.0  11/17/2012
# 17487    52601           29.0  10/30/2013
# 20268    50266           77.0  05/07/2015
# 34568    50314           77.0  05/10/2013
#
# [560637 rows x 6 columns]

# %%
#rename columns
ddf.columns = ['StoreNumber', 'StoreName', 'City', 'ZipCode', 'CountyNumber', 'Date']

# %%
#prepping to check for NA values in columns
idx_na = ddf['StoreNumber'].isna()
name_na = ddf['StoreName'].isna()
city_na = ddf['City'].isna()
zip_na = ddf['ZipCode'].isna()
county_na = ddf['CountyNumber'].isna()
date_na = ddf['Date'].isna()

# %%
#checks for NA store number
ddf[idx_na]
# Out:
# Empty DataFrame
# Columns: [StoreNumber, StoreName, City, ZipCode, CountyNumber, Date]
# Index: []

# %%
#checks for NA store name
ddf[name_na]
# Out:
# Empty DataFrame
# Columns: [StoreNumber, StoreName, City, ZipCode, CountyNumber, Date]
# Index: []

# %%
#checks for NA city
ddf[city_na]
# Out:
#        StoreNumber                               StoreName  City ZipCode  \
# 22762         5140                           A to Z Liquor  None    None
# 29439         5140                           A to Z Liquor  None    None
# 39417         5140                           A to Z Liquor  None    None
# 40799         5251                        Northside Liquor  None    None
# 18710         2539          Hy-Vee Food Store / Iowa Falls  None    None
# ...            ...                                     ...   ...     ...
# 40013         4725    Casey's General Store #1548 / Ankeny  None    None
# 40608         5279            Casey's General Store # 2560  None    None
# 29652         3973                     Mmdg Spirits / Ames  None    None
# 16605         4777  Casey's General Store #1365 / Paullina  None    None
# 18121         2543          Hy-Vee Food Store #1 / Ottumwa  None    None
#
#        CountyNumber        Date
# 22762           NaN  04/15/2019
# 29439           NaN  04/09/2019
# 39417           NaN  04/02/2019
# 40799           NaN  04/04/2019
# 18710           NaN  04/01/2019
# ...             ...         ...
# 40013           NaN  09/22/2016
# 40608           NaN  09/28/2016
# 29652           NaN  09/30/2016
# 16605           NaN  11/28/2017
# 18121           NaN  12/08/2017
#
# [1736 rows x 6 columns]

# %%
#checks for NA zip code
ddf[zip_na]
# Out:
#        StoreNumber                               StoreName  City ZipCode  \
# 22762         5140                           A to Z Liquor  None    None
# 29439         5140                           A to Z Liquor  None    None
# 39417         5140                           A to Z Liquor  None    None
# 40799         5251                        Northside Liquor  None    None
# 18710         2539          Hy-Vee Food Store / Iowa Falls  None    None
# ...            ...                                     ...   ...     ...
# 40013         4725    Casey's General Store #1548 / Ankeny  None    None
# 40608         5279            Casey's General Store # 2560  None    None
# 29652         3973                     Mmdg Spirits / Ames  None    None
# 16605         4777  Casey's General Store #1365 / Paullina  None    None
# 18121         2543          Hy-Vee Food Store #1 / Ottumwa  None    None
#
#        CountyNumber        Date
# 22762           NaN  04/15/2019
# 29439           NaN  04/09/2019
# 39417           NaN  04/02/2019
# 40799           NaN  04/04/2019
# 18710           NaN  04/01/2019
# ...             ...         ...
# 40013           NaN  09/22/2016
# 40608           NaN  09/28/2016
# 29652           NaN  09/30/2016
# 16605           NaN  11/28/2017
# 18121           NaN  12/08/2017
#
# [1737 rows x 6 columns]

# %%
#checks for NA county number
ddf[county_na]
# Out:
#        StoreNumber                               StoreName        City  \
# 2052          4247           Fareway Stores #879 / Belmond     BELMOND
# 2951          3782               Bender Foods / Guttenberg  GUTTENBERG
# 4260          4247           Fareway Stores #879 / Belmond     BELMOND
# 4300          4247           Fareway Stores #879 / Belmond     BELMOND
# 5372          3782               Bender Foods / Guttenberg  GUTTENBERG
# ...            ...                                     ...         ...
# 40013         4725    Casey's General Store #1548 / Ankeny        None
# 40608         5279            Casey's General Store # 2560        None
# 29652         3973                     Mmdg Spirits / Ames        None
# 16605         4777  Casey's General Store #1365 / Paullina        None
# 18121         2543          Hy-Vee Food Store #1 / Ottumwa        None
#
#       ZipCode  CountyNumber        Date
# 2052    50421           NaN  01/20/2015
# 2951    52052           NaN  07/16/2012
# 4260    50421           NaN  09/08/2015
# 4300    50421           NaN  11/10/2015
# 5372    52052           NaN  10/14/2013
# ...       ...           ...         ...
# 40013    None           NaN  09/22/2016
# 40608    None           NaN  09/28/2016
# 29652    None           NaN  09/30/2016
# 16605    None           NaN  11/28/2017
# 18121    None           NaN  12/08/2017
#
# [3611 rows x 6 columns]

# %%
#checks for NA date
ddf[date_na]
# Out:
# Empty DataFrame
# Columns: [StoreNumber, StoreName, City, ZipCode, CountyNumber, Date]
# Index: []

# %%
#convert store numbers to integer type
ddf.loc[:, 'StoreNumber'] = ddf['StoreNumber'].astype(int)

# %%
#convert county numbers to integer type and fills na's as 9999
ddf.loc[:, 'CountyNumber'] = ddf['CountyNumber'].fillna(9999).astype(int)

# %%
#convert date column to date type
ddf['Date'] = pd.to_datetime(ddf['Date'], infer_datetime_format=True)

# %%
#sort by date
ddf = ddf.sort_values(by='Date')

# %%
#filter out data before 2018
ddf = ddf[ddf['Date'] >= '2018-01-01']

# %%
ddf
# Out:
#        StoreNumber                              StoreName             City  \
# 24166         5224    Keystone Liquor & Wine / Coralville       Coralville
# 24130         4872  Casey's General Store #2644 / Earlham          Earlham
# 21828         5254                        Discount Liquor     Cedar Rapids
# 23760         4485                    DYNO'S 51 / SANBORN          Sanborn
# 24246         4900                 Kwik Stop 4 / Waterloo         Waterloo
# ...            ...                                    ...              ...
# 22030         4379        Kum & Go #2091 / Ashworth / WDM  West Des Moines
# 22131         5909                    EZ Stop 1 / Dubuque          Dubuque
# 22176         6046      Casey's General Store #2150 / WDM  West Des Moines
# 21167         6240                    Raceway 80 / Newton           Newton
# 350           5894            Whiskey Business / Allerton         Allerton
#
#       ZipCode  CountyNumber       Date
# 24166   52241            52 2018-01-02
# 24130   50072            61 2018-01-02
# 21828   52402            57 2018-01-02
# 23760   51248            71 2018-01-02
# 24246   50703             7 2018-01-02
# ...       ...           ...        ...
# 22030   50266            77 2022-02-28
# 22131   52001            31 2022-02-28
# 22176   50265            77 2022-02-28
# 21167   50208            50 2022-02-28
# 350     50008            93 2022-02-28
#
# [259939 rows x 6 columns]

# %%
#export df as csv
ddf.to_csv('./data/store.csv')

# %% [markdown]
# ### Transactions Sub-Frame

# %%
#reread in parquet files
ddf = dd.read_parquet('./data/parquet/data-*.parquet')

# %%
#select transaction info columns
ddf = ddf[transaction_info]

# %%
#filter out data from before 2018
ddf = ddf.loc[ddf['Date'].str.contains('2018|2019|2020|2021|2022', regex = True)].compute()

# %%
#rename columns
ddf.columns = ['InvoiceNumber', 'Date', 'StoreNumber', 'Category', 'VendorNumber', 'ItemNumber', 'BottlesSold', 'Sale']

# %%
#change invoice number to index
ddf = ddf.set_index('InvoiceNumber')

# %%
#convert date column to date type
ddf['Date'] = pd.to_datetime(ddf['Date'], infer_datetime_format=True)

# %%
#convert store numbers to integer type
ddf.loc[:, 'StoreNumber'] = ddf['StoreNumber'].astype(int)

# %%
#convert category to integer type and fills na's as 9999999
ddf.loc[:, 'Category'] = ddf['Category'].fillna(9999999).astype(int)

# %%
#convert vendor numbers to integer type and fills na's as 9999
ddf.loc[:, 'VendorNumber'] = ddf['VendorNumber'].fillna(9999).astype(int)

# %%
#convert item numbers to integer type
ddf.loc[:, 'ItemNumber'] = ddf['ItemNumber'].astype(int)

# %%
#convert bottles sold to integer type
ddf.loc[:, 'BottlesSold'] = ddf['BottlesSold'].astype(int)

# %%
#sort by date
ddf = ddf.sort_values(by='Date')

# %%
ddf
# Out:
#                       Date  StoreNumber  Category  VendorNumber  ItemNumber  \
# InvoiceNumber
# INV-09556300101 2018-01-02         5427   1032200           370       34117
# INV-09554900093 2018-01-02         5054   1082000           192       65251
# INV-09550400102 2018-01-02         2549   1031100           380       37348
# INV-09553400013 2018-01-02         5060   1011400            85       26821
# INV-09567800102 2018-01-02         2505   1081600           434       86833
# ...                    ...          ...       ...           ...         ...
# INV-45128200002 2022-02-28         5092   1062400           260       43338
# INV-45123700017 2022-02-28         2527   1022100           395       87410
# INV-45134400008 2022-02-28         4569   1011100           260       25608
# INV-45130800026 2022-02-28         2630   1071100            65       63321
# INV-45118300005 2022-02-28         4652   1051100           205       52582
#
#                  BottlesSold     Sale
# InvoiceNumber
# INV-09556300101            2    44.98
# INV-09554900093            1    44.30
# INV-09550400102            6    68.40
# INV-09553400013            1    13.59
# INV-09567800102            2    13.98
# ...                      ...      ...
# INV-45128200002            1    27.00
# INV-45123700017           60  1935.00
# INV-45134400008            1    19.44
# INV-45130800026           12   117.00
# INV-45118300005            5    54.30
#
# [10346818 rows x 7 columns]

# %%
#export df as csv
ddf.to_csv('./data/transaction.csv')

# %% [markdown]
# ### Categories Sub-Frame

# %%
#reread in parquet files
ddf = dd.read_parquet('./data/parquet/data-*.parquet')

# %%
#select category info columns
ddf = ddf[category_info]

# %%
ddf = ddf.drop_duplicates().compute()

# %%
#rename columns
ddf.columns = ['Category', 'CategoryName']

# %%
#convert category to integer type and fills na's as 9999999
ddf.loc[:, 'Category'] = ddf['Category'].fillna(9999999).astype(int)

# %%
#sort by category name
ddf = ddf.sort_values(by='CategoryName')

# %%
ddf
# Out:
#        Category         CategoryName
# 73      1031100      100 PROOF VODKA
# 17660   1022200   100% Agave Tequila
# 4478    1082010  AMARETTO - IMPORTED
# 419     1101100     AMERICAN ALCOHOL
# 199     1081010    AMERICAN AMARETTO
# ...         ...                  ...
# 15173   1011700                 None
# 28254   1091300                 None
# 29789   1092100                 None
# 9657    1022300                 None
# 23464   1091200                 None
#
# [155 rows x 2 columns]

# %%
#export df as csv
ddf.to_csv('./data/category.csv')
