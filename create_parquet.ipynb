# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import numpy as np
import dask.dataframe as dd
import dask.array as da
import dask.bag as dbs

# %% [markdown]
# ### Import Data

# %%
#creates dask dataframe
ddf = dd.read_csv('./data/Iowa_Liquor_Sales.csv', dtype = {'Category': 'float64',
                                                    'County Number': 'float64',
                                                    'Zip Code': 'object',
                                                    'Vendor Number': 'float64',
                                                    'Item Number': 'object'},
                                            blocksize = '10MB').reset_index()

# %%
#check size of file for correct number of rows
ddf.shape[0].compute()
# Out:
# 23346088

# %%
#convert to parquet file
ddf.to_parquet('./data/parquet/', name_function = lambda x: f"data-{x}.parquet")
# Out:
# (None,)

# %%
ddf.head()
# Out:
#    index Invoice/Item Number        Date  Store Number  \
# 0      0        S05911400012  06/06/2012          4011
# 1      1        S15996500130  12/02/2013          2515
# 2      2        S24885900015  04/06/2015          3461
# 3      3        S21928500011  10/22/2014          2500
# 4      4        S13625500015  07/30/2013          2565
#
#                           Store Name             Address        City Zip Code  \
# 0        Jim and Charlies Affiliated   121 NORTH CLINTON       ALBIA    52531
# 1  Hy-Vee Food Store #1 / Mason City      2400 4TH ST SW  MASON CITY    50401
# 2            Hometown Foods / Stuart   611 S DIVISION ST      STUART    50250
# 3        Hy-Vee Food Store #1 / Ames  3800 W LINCOLN WAY        AMES    50010
# 4        Hy-Vee Food Store / Spencer     819 N GRAND AVE     SPENCER    51301
#
#                          Store Location  County Number  ... Item Number  \
# 0          POINT (-92.808389 41.028644)           68.0  ...       36308
# ...
